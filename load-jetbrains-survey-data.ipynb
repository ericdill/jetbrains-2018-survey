# %%
import pandas as pd

# %%
ls
# Out:
# Untitled.ipynb              python_psf_external_18.csv

# %%
df = pd.read_csv('python_psf_external_18.csv', index_col=0)

# %%
df.head()
# Out:
#   Is Python the main language you use for your current projects?  \
# 1     No, I don’t use Python for my current projects
# 2     No, I don’t use Python for my current projects
# 3     No, I don’t use Python for my current projects
# 4     No, I don’t use Python for my current projects
# 5     No, I don’t use Python for my current projects
#
#   None:What other language(s) do you use?  \
# 1                                    None
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
#
#   Java:What other language(s) do you use?  \
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                    Java
# 5                                    Java
#
#   JavaScript:What other language(s) do you use?  \
# 1                                           NaN
# ...
